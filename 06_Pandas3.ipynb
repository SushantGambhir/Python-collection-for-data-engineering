# %% [markdown]
# # Joining Data in Pandas Dataframes
#
# Here are the steps involved in joining data using Pandas Dataframe APIs.
#
# - First, we need to define index for both the dataframes that are supposed to be joined.
# - Use join to join the Dataframes based on index. The default join is left, we need to make sure right join is used based on the requirement.
#
# In our case, we will join orders and customers using inner join.

# %%
import json

# %%
import pandas as pd

# %%
# Define a helper function that returns sorted column names for a given table schema.
def get_column_names(schemas, table_name):
    column_details = schemas[table_name]
    columns = sorted(column_details, key = lambda col: col['column_position'])
    return [col['column_name'] for col in columns]

# %%
schemas = json.load(open('data/retail_db/schemas.json'))

# %%
orders_columns = get_column_names(schemas,'orders')

# %%
orders = pd.read_csv('data/retail_db/orders/part-00000',names=orders_columns)

# %%
orders
# Out:
#        order_id             order_date  order_customer_id     order_status
# 0             1  2013-07-25 00:00:00.0              11599           CLOSED
# 1             2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2             3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827           CLOSED
# 4             5  2013-07-25 00:00:00.0              11318         COMPLETE
# ...         ...                    ...                ...              ...
# 68878     68879  2014-07-09 00:00:00.0                778         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0               2518  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0              10000          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0               5533         COMPLETE
#
# [68883 rows x 4 columns]

# %%
customer_columns = get_column_names(schemas,'customers')

# %%
customers = pd.read_csv('data/retail_db/customers/part-00000',names=orders_columns)

# %%
customer_columns
# Out:
# ['customer_id',
#  'customer_fname',
#  'customer_lname',
#  'customer_email',
#  'customer_password',
#  'customer_street',
#  'customer_city',
#  'customer_state',
#  'customer_zipcode']

# %%
customers
# Out:
#                                                                 order_id  \
# 1     Richard  Hernandez XXXXXXXXX XXXXXXXXX          6303 Heather Plaza
# 2     Mary     Barrett   XXXXXXXXX XXXXXXXXX     9526 Noble Embers Ridge
# 3     Ann      Smith     XXXXXXXXX XXXXXXXXX      3422 Blue Pioneer Bend
# 4     Mary     Jones     XXXXXXXXX XXXXXXXXX          8324 Little Common
# 5     Robert   Hudson    XXXXXXXXX XXXXXXXXX      10 Crystal River Mall
# ...                                                                  ...
# 12431 Mary     Rios      XXXXXXXXX XXXXXXXXX           1221 Cinder Pines
# 12432 Angela   Smith     XXXXXXXXX XXXXXXXXX  1525 Jagged Barn Highlands
# 12433 Benjamin Garcia    XXXXXXXXX XXXXXXXXX    5459 Noble Brook Landing
# 12434 Mary     Mills     XXXXXXXXX XXXXXXXXX        9720 Colonial Parade
# 12435 Laura    Horton    XXXXXXXXX XXXXXXXXX            5736 Honey Downs
#
#                                                order_date order_customer_id  \
# ...

# %%
orders_columns
# Out:
# ['order_id', 'order_date', 'order_customer_id', 'order_status']

# %%
orders
# Out:
#        order_id             order_date  order_customer_id     order_status
# 0             1  2013-07-25 00:00:00.0              11599           CLOSED
# 1             2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2             3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827           CLOSED
# 4             5  2013-07-25 00:00:00.0              11318         COMPLETE
# ...         ...                    ...                ...              ...
# 68878     68879  2014-07-09 00:00:00.0                778         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0               2518  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0              10000          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0               5533         COMPLETE
#
# [68883 rows x 4 columns]
